# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read dataset
data = pd.read_csv("C:\\Users\\Mustafa\\OneDrive\\Desktop\\SANDIP UNIVERSITY\\PROGRAM\\PYTHON\\PRODIGY INFOTECH\\archive\\cities_r2.csv")

# %%
data.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# ...

# %%
data.describe()
# Out:
#        state_code   dist_code  population_total  population_male  \
# count  493.000000  493.000000      4.930000e+02     4.930000e+02
# mean    18.643002   16.782961      4.481124e+05     2.343468e+05
# std      9.297168   15.566131      1.033228e+06     5.487786e+05
# min      1.000000    1.000000      1.000360e+05     5.020100e+04
# 25%      9.000000    7.000000      1.261420e+05     6.638400e+04
# 50%     19.000000   13.000000      1.841330e+05     9.665500e+04
# 75%     27.000000   21.000000      3.490330e+05     1.750550e+05
# max     35.000000   99.000000      1.247845e+07     6.736815e+06
#
#        population_female  0-6_population_total  0-6_population_male  \
# count       4.930000e+02          4.930000e+02           493.000000
# mean        2.137656e+05          4.709285e+04         24849.527383
# std         4.848622e+05          1.050279e+05         55535.310272
# min         4.512600e+04          6.547000e+03          3406.000000
# ...

# %%
# Print the columns in the dataset
print("Columns in the dataset:", data.columns)
# Out:
# Columns in the dataset: Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates'],
#       dtype='object')

# %%
# Assuming the dataset has a column for the distribution (replace 'YourColumnName' with the correct column name)
column_name = 'population_total'
column_counts = data[column_name].value_counts()

# %%
# Plot the bar chart
plt.figure(figsize=(12, 6))
column_counts.plot(kind='bar', color='skyblue')
plt.title(f'Distribution of Cities Based on {column_name}')
plt.xlabel(column_name)
plt.ylabel('Number of Cities')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
data.columns
# Out:
# Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates'],
#       dtype='object')

# %%
# Now lets see for  state names
column_name = 'state_name'
column_counts = data[column_name].value_counts()

# %%
# Plot the bar chart
plt.figure(figsize=(12, 6))
column_counts.plot(kind='bar', color='skyblue')
plt.title(f'Distribution of Cities Based on {column_name}')
plt.xlabel(column_name)
plt.ylabel('Number of Cities')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
data.columns
# Out:
# Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates'],
#       dtype='object')

# %%
# Now lets see for names of city
column_name = 'name_of_city'
column_counts = data[column_name].value_counts()

# %%
# Assuming the dataset has a numerical column for the histogram (replace 'YourNumericalColumn' with the correct column name)
numerical_column = 'name_of_city'  # Replace with the correct numerical column name

# %%
# Plot the histogram
plt.figure(figsize=(12, 6))
plt.hist(data[numerical_column], bins=30, color='skyblue', edgecolor='black')
plt.title(f'Histogram of {numerical_column}')
plt.xlabel(numerical_column)
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
data.columns
# Out:
# Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates'],
#       dtype='object')

# %%
# Now lets see for names of city
column_name = 'literates_total'
column_counts = data[column_name].value_counts()

# %%
# Plot the bar chart
plt.figure(figsize=(12, 6))
column_counts.plot(kind='bar', color='skyblue')
plt.title(f'bar chart Distribution of Cities Based on {column_name}')
plt.xlabel(column_name)
plt.ylabel('Number of Cities')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Assuming the dataset has a numerical column for the histogram (replace 'YourNumericalColumn' with the correct column name)
numerical_column = 'literates_total'  # Replace with the correct numerical column name

# %%
# Plot the histogram
plt.figure(figsize=(12, 6))
plt.hist(data[numerical_column], bins=30, color='skyblue', edgecolor='black')
plt.title(f'Histogram of {numerical_column}')
plt.xlabel(numerical_column)
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
